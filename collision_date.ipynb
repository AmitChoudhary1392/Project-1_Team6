# %%
import pandas as pd
import numpy as np

# %%
data_bin= pd.read_csv('clean_collision.csv', parse_dates = [['Date', 'Time']])
data_bin
# Out:
#                  Date_Time  Unnamed: 0  Year Collision Type Descriptor  \
# 0      2016-05-15 10:38:00      299452  2016                   HEAD ON
# 1      2016-05-20 00:00:00      299453  2016                   Unknown
# 2      2016-08-15 19:29:00      299454  2016                     OTHER
# 3      2016-03-30 12:55:00      299457  2016                OVERTAKING
# 4      2016-07-09 20:10:00      299459  2016                     OTHER
# 5      2016-06-01 16:00:00      299464  2016            RIGHT TURN (6)
# 6      2016-11-13 23:35:00      299467  2016                     OTHER
# 7      2016-10-20 05:45:00      299472  2016                     OTHER
# 8      2016-10-30 02:30:00      299473  2016               RIGHT ANGLE
# 9      2016-07-01 14:27:00      299476  2016                  REAR END
# 10     2016-09-19 14:23:00      299479  2016                     OTHER
# 11     2016-11-14 20:30:00      299482  2016                     OTHER
# ...

# %%
data_bin.sort_values(by='Date_Time',ascending=True)
# Out:
#                  Date_Time  Unnamed: 0  Year Collision Type Descriptor  \
# 127615 2016-01-01 00:00:00      551736  2016                   Unknown
# 41675  2016-01-01 00:00:00      381657  2016                     OTHER
# 149615 2016-01-01 00:00:00      595362  2016                   Unknown
# 101267 2016-01-01 00:00:00      499369  2016               RIGHT ANGLE
# 214006 2016-01-01 00:00:00      722407  2016                     OTHER
# 131751 2016-01-01 00:00:00      559999  2016               RIGHT ANGLE
# 158553 2016-01-01 00:00:00      613181  2016                   Unknown
# 101321 2016-01-01 00:00:00      499464  2016                   Unknown
# 13483  2016-01-01 00:00:00      326182  2016                     OTHER
# 9108   2016-01-01 00:00:00      317438  2016                     OTHER
# 80722  2016-01-01 00:00:00      458883  2016                     OTHER
# 237514 2016-01-01 00:00:00      768991  2016                OVERTAKING
# ...

# %%
data_bin = data_bin[['Year','Date_Time', 'Collision Type Descriptor', 'Road Surface Conditions', 'Weather Conditions', 'Number of Vehicles Involved']]
data_bin
# Out:
#         Year           Date_Time Collision Type Descriptor  \
# 0       2016 2016-05-15 10:38:00                   HEAD ON
# 1       2016 2016-05-20 00:00:00                   Unknown
# 2       2016 2016-08-15 19:29:00                     OTHER
# 3       2016 2016-03-30 12:55:00                OVERTAKING
# 4       2016 2016-07-09 20:10:00                     OTHER
# 5       2016 2016-06-01 16:00:00            RIGHT TURN (6)
# 6       2016 2016-11-13 23:35:00                     OTHER
# 7       2016 2016-10-20 05:45:00                     OTHER
# 8       2016 2016-10-30 02:30:00               RIGHT ANGLE
# 9       2016 2016-07-01 14:27:00                  REAR END
# 10      2016 2016-09-19 14:23:00                     OTHER
# 11      2016 2016-11-14 20:30:00                     OTHER
# 12      2016 2016-01-20 14:40:00                     OTHER
# 13      2016 2016-05-31 08:00:00                  REAR END
# 14      2016 2016-07-29 16:22:00                  REAR END
# ...

# %%
data_bin.to_csv("clean_collision1.csv", mode="w")
