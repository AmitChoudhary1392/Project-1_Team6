# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_city= pd.read_csv('us-traffic-2015/dot_traffic_2015.txt/dot_traffic_2015.csv')
data_city.head()
# Out:
#          date  day_of_data  day_of_week  direction_of_travel  \
# 0  2015-04-07            7            3                    1
# 1  2015-09-26           26            7                    7
# 2  2015-06-16           16            3                    3
# 3  2015-04-26           26            1                    5
# 4  2015-05-23           23            7                    3
#
#   direction_of_travel_name  fips_state_code functional_classification  \
# 0                    North               56                        3R
# 1                     West               21                        1U
# 2                     East                6                        1U
# 3                    South               55                        1U
# 4                     East                4                        4R
#
#            functional_classification_name  lane_of_travel  month_of_data  ...  \
# 0       Rural: Principal Arterial - Other               1              4  ...
# ...
