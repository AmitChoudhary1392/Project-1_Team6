# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
input_file= pd.read_csv('weather_merged.csv')
df=pd.DataFrame(input_file)
df.head()
# Out:
#    Unnamed: 0         City        Country   Latitude   Longitude  \
# 0           0  Albuquerque  United States  35.084492 -106.651138
# 1           1  Albuquerque  United States  35.084492 -106.651138
# 2           2  Albuquerque  United States  35.084492 -106.651138
# 3           3  Albuquerque  United States  35.084492 -106.651138
# 4           4  Albuquerque  United States  35.084492 -106.651138
#
#               datetime  Temperature in Kelvin
# 0  2012-10-01 13:00:00             285.120000
# 1  2012-10-01 14:00:00             285.154558
# 2  2012-10-01 15:00:00             285.233952
# 3  2012-10-01 16:00:00             285.313345
# 4  2012-10-01 17:00:00             285.392738

# %%
df['datetimeobj'] =  pd.to_datetime(df['datetime'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
type(df['datetimeobj'][0])

# %%
df['hour']= df['datetimeobj'].dt.hour
df.head()
# Out:
#    Unnamed: 0         City        Country   Latitude   Longitude  \
# 0           0  Albuquerque  United States  35.084492 -106.651138
# 1           1  Albuquerque  United States  35.084492 -106.651138
# 2           2  Albuquerque  United States  35.084492 -106.651138
# 3           3  Albuquerque  United States  35.084492 -106.651138
# 4           4  Albuquerque  United States  35.084492 -106.651138
#
#               datetime  Temperature in Kelvin         datetimeobj  hour
# 0  2012-10-01 13:00:00             285.120000 2012-10-01 13:00:00    13
# 1  2012-10-01 14:00:00             285.154558 2012-10-01 14:00:00    14
# 2  2012-10-01 15:00:00             285.233952 2012-10-01 15:00:00    15
# 3  2012-10-01 16:00:00             285.313345 2012-10-01 16:00:00    16
# 4  2012-10-01 17:00:00             285.392738 2012-10-01 17:00:00    17

# %%
df['year']=df['datetimeobj'].dt.year
df['Month']=df['datetimeobj'].dt.month
df['']
df.head()

# %%
input_file2= pd.read_csv('clean_collision.csv')
input_file2.head()
# Out:
#    Unnamed: 0  Year   Time        Date Collision Type Descriptor  \
# 0      299452  2016  10:38  05/15/2016                   HEAD ON
# 1      299453  2016   0:00  05/20/2016                   Unknown
# 2      299454  2016  19:29  08/15/2016                     OTHER
# 3      299457  2016  12:55  03/30/2016                OVERTAKING
# 4      299459  2016  20:10  07/09/2016                     OTHER
#
#   Road Surface Conditions Weather Conditions  Number of Vehicles Involved
# 0                     Dry             Cloudy                            2
# 1                     Dry              Clear                            2
# 2                     Dry             Cloudy                            1
# 3                     Dry              Clear                            2
# 4                     Wet               Rain                            1

# %%
input_file2['dateobj'] =  pd.to_datetime(input_file2['Date'], format='%m/%d/%Y')
input_file2.head()
# Out:
#    Unnamed: 0  Year   Time        Date Collision Type Descriptor  \
# 0      299452  2016  10:38  05/15/2016                   HEAD ON
# 1      299453  2016   0:00  05/20/2016                   Unknown
# 2      299454  2016  19:29  08/15/2016                     OTHER
# 3      299457  2016  12:55  03/30/2016                OVERTAKING
# 4      299459  2016  20:10  07/09/2016                     OTHER
#
#   Road Surface Conditions Weather Conditions  Number of Vehicles Involved  \
# 0                     Dry             Cloudy                            2
# 1                     Dry              Clear                            2
# 2                     Dry             Cloudy                            1
# 3                     Dry              Clear                            2
# 4                     Wet               Rain                            1
#
#      dateobj
# 0 2016-05-15
# 1 2016-05-20
# 2 2016-08-15
# 3 2016-03-30
# 4 2016-07-09

# %%
input_file2['datetime'] =  pd.to_datetime(input_file2[['Date', 'Time']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-c345af083807> in <module>
# ----> 1 input_file2['datetime'] =  pd.to_datetime(input_file2[['Date', 'Time']])
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
# --> 595         result = _assemble_from_unit_mappings(arg, errors, box, tz)
#     596     elif isinstance(arg, ABCIndexClass):
#     597         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _assemble_from_unit_mappings(arg, errors, box, tz)
# ...

# %%
data = pd.read_csv('clean_collision.csv', parse_dates=[['Date', 'Time']) 
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-33e2ab9c178c> in <module>
# ----> 1 data = pd.read_csv('clean_collision.csv', parse_dates=[['Date', 'Time']], drop=False)
#       2 data.head()
#
# TypeError: parser_f() got an unexpected keyword argument 'drop'

# %%
data['Date_Time']
# Out:
# 0        2016-05-15 10:38:00
# 1        2016-05-20 00:00:00
# 2        2016-08-15 19:29:00
# 3        2016-03-30 12:55:00
# 4        2016-07-09 20:10:00
# 5        2016-06-01 16:00:00
# 6        2016-11-13 23:35:00
# 7        2016-10-20 05:45:00
# 8        2016-10-30 02:30:00
# 9        2016-07-01 14:27:00
# 10       2016-09-19 14:23:00
# 11       2016-11-14 20:30:00
# 12       2016-01-20 14:40:00
# 13       2016-05-31 08:00:00
# 14       2016-07-29 16:22:00
# 15       2016-04-18 12:58:00
# 16       2016-02-12 17:08:00
# 17       2016-10-30 09:00:00
# 18       2016-09-23 20:00:00
# 19       2016-02-17 14:05:00
# 20       2016-04-19 12:20:00
# 21       2016-06-25 18:00:00
# 22       2016-04-02 21:25:00
# 23       2016-03-20 12:31:00
# 24       2016-07-04 23:58:00
# 25       2016-08-28 16:15:00
# 26       2016-11-18 03:40:00
# 27       2016-05-09 23:41:00
# 28       2016-11-01 14:45:00
# 29       2016-06-24 06:40:00
#                  ...
# 301878   2016-10-07 15:10:00
# ...
