# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# # City Data

# %%
data_city= pd.read_csv('Raw Data/Historical weather data/Data_files_used/city_attributes.csv')
data_city.head()
# Out:
#             City        Country   Latitude   Longitude
# 0      Vancouver         Canada  49.249660 -123.119339
# 1       Portland  United States  45.523449 -122.676208
# 2  San Francisco  United States  37.774929 -122.419418
# 3        Seattle  United States  47.606209 -122.332069
# 4    Los Angeles  United States  34.052231 -118.243683

# %% [markdown]
# # Humidity

# %%
#Read humidity data file as csv 
data_humidity=pd.read_csv('Raw Data/Historical weather data/Data_files_used/humidity.csv', index_col='datetime', parse_dates=['datetime'])

#save dataframe and rename columns
df_humidity= pd.DataFrame(data_humidity['New York']).rename(columns={'New York':'Humidity(%)'})

df_humidity.head()
# Out:
#                      Humidity(%)
# datetime
# 2012-10-01 12:00:00          NaN
# 2012-10-01 13:00:00         58.0
# 2012-10-01 14:00:00         57.0
# 2012-10-01 15:00:00         57.0
# 2012-10-01 16:00:00         57.0

# %% [markdown]
# # Pressure

# %%
#Read pressure data file as csv 
data_pressure=pd.read_csv('Raw Data/Historical weather data/Data_files_used/pressure.csv',index_col='datetime', parse_dates=['datetime'])

#save dataframe and rename columns
df_pressure= pd.DataFrame(data_pressure['New York']).rename(columns={'New York':'Pressure(Torr)'})

#Show DataFrame
df_pressure.head()
# Out:
#                      Pressure(Torr)
# datetime
# 2012-10-01 12:00:00             NaN
# 2012-10-01 13:00:00          1012.0
# 2012-10-01 14:00:00          1012.0
# 2012-10-01 15:00:00          1012.0
# 2012-10-01 16:00:00          1012.0

# %% [markdown]
# # Temperature

# %%
#Read temperature data file as csv 
data_temp=pd.read_csv('Raw Data/Historical weather data/Data_files_used/temperature.csv', index_col='datetime', parse_dates=['datetime'])

#save dataframe and rename columns
df_temp= pd.DataFrame(data_temp['New York']).rename(columns={'New York':'Temp(K)'})

#convert temperature in Kelvin to degree Celcius
df_temp['Temp(C)']= df_temp['Temp(K)']- 273.15

#Show DataFrame
df_temp.head()
# Out:
#                         Temp(K)    Temp(C)
# datetime
# 2012-10-01 12:00:00         NaN        NaN
# 2012-10-01 13:00:00  288.220000  15.070000
# 2012-10-01 14:00:00  288.247676  15.097676
# 2012-10-01 15:00:00  288.326940  15.176940
# 2012-10-01 16:00:00  288.406203  15.256203

# %% [markdown]
# # Weather Description

# %%
#Read Weather data file as csv 
data_weather=pd.read_csv('Raw Data/Historical weather data/Data_files_used/weather_description.csv', index_col='datetime', parse_dates=['datetime'])

#save dataframe and rename columns
df_weather= pd.DataFrame(data_weather['New York']).rename(columns={'New York':'Weather'})

#Show DataFrame
df_weather.head()
# Out:
#                         Weather
# datetime
# 2012-10-01 12:00:00         NaN
# 2012-10-01 13:00:00  few clouds
# 2012-10-01 14:00:00  few clouds
# 2012-10-01 15:00:00  few clouds
# 2012-10-01 16:00:00  few clouds

# %% [markdown]
# # Wind Speed

# %%
#Read Weather data file as csv 
data_windspeed=pd.read_csv('Raw Data/Historical weather data/Data_files_used/wind_speed.csv',index_col='datetime', parse_dates=['datetime'])

#save dataframe and rename columns
df_windspeed= pd.DataFrame(data_windspeed['New York']).rename(columns={'New York':'Wind Speed'})

#Show DataFrame
df_windspeed.head()
# Out:
#                      Wind Speed
# datetime
# 2012-10-01 12:00:00         NaN
# 2012-10-01 13:00:00         7.0
# 2012-10-01 14:00:00         7.0
# 2012-10-01 15:00:00         7.0
# 2012-10-01 16:00:00         7.0

# %% [markdown]
# # Combined City Data

# %%
#df= [df_temp, df_humidity, df_pressure, df_weather, df_windspeed]

#Create DataFrames to merge weather data for New York

df1= pd.merge(df_temp, df_humidity, on='datetime', how='outer')
df2=pd.merge(df1, df_pressure, on='datetime', how='outer')
df3=pd.merge(df2, df_weather, on='datetime', how='outer')
df4=pd.merge(df3,df_windspeed, on='datetime', how='outer')

#Create date time object
df4=df4.reset_index()
df4['datetimeobj'] =  pd.to_datetime(df4['datetime'], format='%Y-%m-%d %H:%M:%S.%f')

#Define final weather_data DataFrame

weather_data_NY=pd.DataFrame(df4)
weather_data_NY['Year']= df4['datetime'].dt.year
weather_data_NY['Month']= df4['datetime'].dt.month
weather_data_NY['Day']= df4['datetime'].dt.day

weather_data_NY['Hour']= df4['datetime'].dt.hour

#Rearrange Columns for the final dataframe and set index

weather_data_NY=weather_data_NY.loc[:, ['datetime','Year','Month','Day','Hour','Temp(K)','Temp(C)','Humidity(%)',
                                        'Pressure(Torr)','Weather','Wind Speed']]
weather_data_NY.head()
# Out:
#              datetime  Year  Month  Day  Hour     Temp(K)    Temp(C)  \
# 0 2012-10-01 12:00:00  2012     10    1    12         NaN        NaN
# 1 2012-10-01 13:00:00  2012     10    1    13  288.220000  15.070000
# 2 2012-10-01 14:00:00  2012     10    1    14  288.247676  15.097676
# 3 2012-10-01 15:00:00  2012     10    1    15  288.326940  15.176940
# 4 2012-10-01 16:00:00  2012     10    1    16  288.406203  15.256203
#
#    Humidity(%)  Pressure(Torr)     Weather  Wind Speed
# 0          NaN             NaN         NaN         NaN
# 1         58.0          1012.0  few clouds         7.0
# 2         57.0          1012.0  few clouds         7.0
# 3         57.0          1012.0  few clouds         7.0
# 4         57.0          1012.0  few clouds         7.0

# %% [markdown]
# # NYC Cab Ride Data

# %%
# Read csv file containing NYC taxi trip duration data for problem 2
taxi_dataQ2= pd.read_csv('Raw Data/nyc-taxi-trip-duration/NYCtaxi_trip_Q2.csv')
taxi_dataQ2.head()
# Out:
#           id  vendor_id  pickup_datetime dropoff_datetime  passenger_count  \
# 0  id2875421        2.0  3/14/2016 17:24  3/14/2016 17:32              1.0
# 1  id2377394        1.0   6/12/2016 0:43   6/12/2016 0:54              1.0
# 2  id3858529        2.0  1/19/2016 11:35  1/19/2016 12:10              1.0
# 3  id3504673        2.0   4/6/2016 19:32   4/6/2016 19:39              1.0
# 4  id2181028        2.0  3/26/2016 13:30  3/26/2016 13:38              1.0
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
# 3        -74.010040        40.719971         -74.012268         40.706718
# 4        -73.973053        40.793209         -73.972923         40.782520
#
#   store_and_fwd_flag  trip_duration(sec)
# 0                  N               455.0
# 1                  N               663.0
# 2                  N              2124.0
# 3                  N               429.0
# 4                  N               435.0

# %%
taxi_dataQ2['datetime'] =  pd.to_datetime(taxi_dataQ2['pickup_datetime'], format='%m/%d/%Y %H:%M')
taxi_dataQ2['Hour']= taxi_dataQ2['datetime'].dt.hour
taxi_dataQ2['Year']= taxi_dataQ2['datetime'].dt.year
taxi_dataQ2['Month']= taxi_dataQ2['datetime'].dt.month
taxi_dataQ2['Day']= taxi_dataQ2['datetime'].dt.day
taxi_dataQ2.head()
# Out:
#           id  vendor_id  pickup_datetime dropoff_datetime  passenger_count  \
# 0  id2875421        2.0  3/14/2016 17:24  3/14/2016 17:32              1.0
# 1  id2377394        1.0   6/12/2016 0:43   6/12/2016 0:54              1.0
# 2  id3858529        2.0  1/19/2016 11:35  1/19/2016 12:10              1.0
# 3  id3504673        2.0   4/6/2016 19:32   4/6/2016 19:39              1.0
# 4  id2181028        2.0  3/26/2016 13:30  3/26/2016 13:38              1.0
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
# 3        -74.010040        40.719971         -74.012268         40.706718
# 4        -73.973053        40.793209         -73.972923         40.782520
#
#   store_and_fwd_flag  trip_duration(sec)            datetime  Hour    Year  \
# 0                  N               455.0 2016-03-14 17:24:00  17.0  2016.0
# 1                  N               663.0 2016-06-12 00:43:00   0.0  2016.0
# 2                  N              2124.0 2016-01-19 11:35:00  11.0  2016.0
# 3                  N               429.0 2016-04-06 19:32:00  19.0  2016.0
# 4                  N               435.0 2016-03-26 13:30:00  13.0  2016.0
#
#    Month   Day
# 0    3.0  14.0
# 1    6.0  12.0
# 2    1.0  19.0
# 3    4.0   6.0
# 4    3.0  26.0

# %%
# Drop the rows that have NA-values
taxi_dataQ2.dropna(how='all',inplace=True)
taxi_dataQ2.head()
# Out:
#           id  vendor_id  pickup_datetime dropoff_datetime  passenger_count  \
# 0  id2875421        2.0  3/14/2016 17:24  3/14/2016 17:32              1.0
# 1  id2377394        1.0   6/12/2016 0:43   6/12/2016 0:54              1.0
# 2  id3858529        2.0  1/19/2016 11:35  1/19/2016 12:10              1.0
# 3  id3504673        2.0   4/6/2016 19:32   4/6/2016 19:39              1.0
# 4  id2181028        2.0  3/26/2016 13:30  3/26/2016 13:38              1.0
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
# 3        -74.010040        40.719971         -74.012268         40.706718
# 4        -73.973053        40.793209         -73.972923         40.782520
#
#   store_and_fwd_flag  trip_duration(sec)            datetime  Hour    Year  \
# 0                  N               455.0 2016-03-14 17:24:00  17.0  2016.0
# 1                  N               663.0 2016-06-12 00:43:00   0.0  2016.0
# 2                  N              2124.0 2016-01-19 11:35:00  11.0  2016.0
# 3                  N               429.0 2016-04-06 19:32:00  19.0  2016.0
# 4                  N               435.0 2016-03-26 13:30:00  13.0  2016.0
#
#    Month   Day
# 0    3.0  14.0
# 1    6.0  12.0
# 2    1.0  19.0
# 3    4.0   6.0
# 4    3.0  26.0

# %%
# Drop columns that are not required
taxi_dataQ2 = taxi_dataQ2.drop(["vendor_id","pickup_datetime","dropoff_datetime","passenger_count","dropoff_longitude","dropoff_latitude","store_and_fwd_flag"], axis=1)

# Convert 'Hour','Year',and 'Month' to integer
taxi_dataQ2["Hour"] = pd.to_numeric(taxi_dataQ2["Hour"])
taxi_dataQ2["Year"] = pd.to_numeric(taxi_dataQ2["Year"])
taxi_dataQ2["Month"] = pd.to_numeric(taxi_dataQ2["Month"])
taxi_dataQ2["Day"] = pd.to_numeric(taxi_dataQ2["Day"])

taxi_dataQ2["Hour"] = taxi_dataQ2["Hour"].astype(int)
taxi_dataQ2["Year"] = taxi_dataQ2["Year"].astype(int)
taxi_dataQ2["Month"] = taxi_dataQ2["Month"].astype(int)
taxi_dataQ2["Day"] = taxi_dataQ2["Day"].astype(int)

taxi_dataQ2.head()
# Out:
#           id  pickup_longitude  pickup_latitude  trip_duration(sec)  \
# 0  id2875421        -73.982155        40.767937               455.0
# 1  id2377394        -73.980415        40.738564               663.0
# 2  id3858529        -73.979027        40.763939              2124.0
# 3  id3504673        -74.010040        40.719971               429.0
# 4  id2181028        -73.973053        40.793209               435.0
#
#              datetime  Hour  Year  Month  Day
# 0 2016-03-14 17:24:00    17  2016      3   14
# 1 2016-06-12 00:43:00     0  2016      6   12
# 2 2016-01-19 11:35:00    11  2016      1   19
# 3 2016-04-06 19:32:00    19  2016      4    6
# 4 2016-03-26 13:30:00    13  2016      3   26

# %%
# Round off 'datetime' column values around nearest hour
taxi_dataQ2 = taxi_dataQ2.assign(datetime=taxi_dataQ2.datetime.dt.round('H'))
taxi_dataQ2.head()
# Out:
#           id  pickup_longitude  pickup_latitude  trip_duration(sec)  \
# 0  id2875421        -73.982155        40.767937               455.0
# 1  id2377394        -73.980415        40.738564               663.0
# 2  id3858529        -73.979027        40.763939              2124.0
# 3  id3504673        -74.010040        40.719971               429.0
# 4  id2181028        -73.973053        40.793209               435.0
#
#              datetime  Hour  Year  Month  Day
# 0 2016-03-14 17:00:00    17  2016      3   14
# 1 2016-06-12 01:00:00     0  2016      6   12
# 2 2016-01-19 12:00:00    11  2016      1   19
# 3 2016-04-06 20:00:00    19  2016      4    6
# 4 2016-03-26 14:00:00    13  2016      3   26

# %% [markdown]
# # NYC Cab ride data with weather conditions

# %%
ride_data = pd.merge(taxi_dataQ2, weather_data_NY, on='datetime', how='left')
ride_data.head()
# Out:
#           id  pickup_longitude  pickup_latitude  trip_duration(sec)  \
# 0  id2875421        -73.982155        40.767937               455.0
# 1  id2377394        -73.980415        40.738564               663.0
# 2  id3858529        -73.979027        40.763939              2124.0
# 3  id3504673        -74.010040        40.719971               429.0
# 4  id2181028        -73.973053        40.793209               435.0
#
#              datetime  Hour_x  Year_x  Month_x  Year_y  Month_y  Hour_y  \
# 0 2016-03-14 17:00:00      17    2016        3    2016        3      17
# 1 2016-06-12 01:00:00       0    2016        6    2016        6       1
# 2 2016-01-19 12:00:00      11    2016        1    2016        1      12
# 3 2016-04-06 20:00:00      19    2016        4    2016        4      20
# 4 2016-03-26 14:00:00      13    2016        3    2016        3      14
#
#       Temp(K)    Temp(C)  Humidity(%)  Pressure(Torr)           Weather  \
# 0  279.557766   6.407766         81.0          1024.0     moderate rain
# 1  300.340000  27.190000         50.0          1005.0     moderate rain
# 2  264.295125  -8.854875         53.0          1017.0      sky is clear
# 3  280.670000   7.520000         39.0          1021.0              haze
# 4  279.040000   5.890000         52.0          1026.0  scattered clouds
#
#    Wind Speed
# 0         6.0
# 1         4.0
# 2         6.0
# 3         6.0
# 4         4.0

# %%
# Drop columns that are not required
ride_data = ride_data.drop(["Hour_x","Year_x","Month_x"], axis=1)
ride_data.head()
# Out:
#           id  pickup_longitude  pickup_latitude  trip_duration(sec)  \
# 0  id2875421        -73.982155        40.767937               455.0
# 1  id2377394        -73.980415        40.738564               663.0
# 2  id3858529        -73.979027        40.763939              2124.0
# 3  id3504673        -74.010040        40.719971               429.0
# 4  id2181028        -73.973053        40.793209               435.0
#
#              datetime  Year_y  Month_y  Hour_y     Temp(K)    Temp(C)  \
# 0 2016-03-14 17:00:00    2016        3      17  279.557766   6.407766
# 1 2016-06-12 01:00:00    2016        6       1  300.340000  27.190000
# 2 2016-01-19 12:00:00    2016        1      12  264.295125  -8.854875
# 3 2016-04-06 20:00:00    2016        4      20  280.670000   7.520000
# 4 2016-03-26 14:00:00    2016        3      14  279.040000   5.890000
#
#    Humidity(%)  Pressure(Torr)           Weather  Wind Speed
# 0         81.0          1024.0     moderate rain         6.0
# 1         50.0          1005.0     moderate rain         4.0
# 2         53.0          1017.0      sky is clear         6.0
# 3         39.0          1021.0              haze         6.0
# 4         52.0          1026.0  scattered clouds         4.0

# %%
# Rename column labels
ride_data = ride_data.rename(columns={'Year_y':'Year','Month_y':'Month','Hour_y':'Hour'})
ride_data.head()
# Out:
#           id  pickup_longitude  pickup_latitude  trip_duration(sec)  \
# 0  id2875421        -73.982155        40.767937               455.0
# 1  id2377394        -73.980415        40.738564               663.0
# 2  id3858529        -73.979027        40.763939              2124.0
# 3  id3504673        -74.010040        40.719971               429.0
# 4  id2181028        -73.973053        40.793209               435.0
#
#              datetime  Year  Month  Hour     Temp(K)    Temp(C)  Humidity(%)  \
# 0 2016-03-14 17:00:00  2016      3    17  279.557766   6.407766         81.0
# 1 2016-06-12 01:00:00  2016      6     1  300.340000  27.190000         50.0
# 2 2016-01-19 12:00:00  2016      1    12  264.295125  -8.854875         53.0
# 3 2016-04-06 20:00:00  2016      4    20  280.670000   7.520000         39.0
# 4 2016-03-26 14:00:00  2016      3    14  279.040000   5.890000         52.0
#
#    Pressure(Torr)           Weather  Wind Speed
# 0          1024.0     moderate rain         6.0
# 1          1005.0     moderate rain         4.0
# 2          1017.0      sky is clear         6.0
# 3          1021.0              haze         6.0
# 4          1026.0  scattered clouds         4.0

# %%
# Round off temperature values
ride_data = ride_data.round({'Temp(K)': 0, 'Temp(C)': 0})
ride_data.head()
# Out:
#           id  pickup_longitude  pickup_latitude  trip_duration(sec)  \
# 0  id2875421        -73.982155        40.767937               455.0
# 1  id2377394        -73.980415        40.738564               663.0
# 2  id3858529        -73.979027        40.763939              2124.0
# 3  id3504673        -74.010040        40.719971               429.0
# 4  id2181028        -73.973053        40.793209               435.0
#
#              datetime  Year  Month  Hour  Temp(K)  Temp(C)  Humidity(%)  \
# 0 2016-03-14 17:00:00  2016      3    17    280.0      6.0         81.0
# 1 2016-06-12 01:00:00  2016      6     1    300.0     27.0         50.0
# 2 2016-01-19 12:00:00  2016      1    12    264.0     -9.0         53.0
# 3 2016-04-06 20:00:00  2016      4    20    281.0      8.0         39.0
# 4 2016-03-26 14:00:00  2016      3    14    279.0      6.0         52.0
#
#    Pressure(Torr)           Weather  Wind Speed
# 0          1024.0     moderate rain         6.0
# 1          1005.0     moderate rain         4.0
# 2          1017.0      sky is clear         6.0
# 3          1021.0              haze         6.0
# 4          1026.0  scattered clouds         4.0

# %%
ride_data.resample('datetime').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     186             split = name.split('-')
# --> 187             klass = prefix_mapping[split[0]]
#     188             # handles case where there's no suffix (and will TypeError if too
#
# KeyError: 'DATETIME'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in to_offset(freq)
#     153                 stride = int(stride)
# --> 154                 offset = get_offset(name)
#     155                 offset = offset * int(np.fabs(stride) * stride_sign)
#
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     192             # bad prefix or suffix
# --> 193             raise ValueError(libfreqs.INVALID_FREQ_ERR_MSG.format(name))
#     194         # cache
#
# ValueError: Invalid frequency: DATETIME
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-3c87b95207b7> in <module>
# ----> 1 ride_data.resample('datetime').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    8153                      axis=axis, kind=kind, loffset=loffset,
#    8154                      convention=convention,
# -> 8155                      base=base, key=on, level=level)
#    8156         return _maybe_process_deprecations(r,
#    8157                                            how=how,
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1247     Create a TimeGrouper and return our resampler.
#    1248     """
# -> 1249     tg = TimeGrouper(**kwds)
#    1250     return tg._get_resampler(obj, kind=kind)
#    1251
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in __init__(self, freq, closed, label, how, axis, fill_method, limit, loffset, kind, convention, base, **kwargs)
#    1302                              .format(convention))
#    1303
# -> 1304         freq = to_offset(freq)
#    1305
#    1306         end_types = {'M', 'A', 'Q', 'BM', 'BA', 'BQ', 'W'}
#
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in to_offset(freq)
#     159                     delta = delta + offset
#     160         except Exception:
# --> 161             raise ValueError(libfreqs.INVALID_FREQ_ERR_MSG.format(freq))
#     162
#     163     if delta is None:
#
# ValueError: Invalid frequency: datetime

# %%
# Create bins for 'Pickup Time'
bins = ["0:0", "0:59", "1:59", "2:59", "3:59", "4:59", "5:59", "6:59", "7:59", "8:59", "9:59", "10:59",
       "11:59", "12:59", "13:59", "14:59", "15:59", "16:59", "17:59", "18:59", "19:59", "20:59", "21:59", "22:59", "24:00"]
group_names = ["0:00-1:00", "1:00-2:00", "2:00-3:00", "3:00-4:00", "4:00-5:00", "5:00-6:00", "6:00-7:00", "7:00-8:00", 
               "8:00-9:00", "9:00-10:00", "10:00-11:00", "11:00-12:00", "12:00-13:00", "13:00-14:00", "14:00-15:00",
              "15:00-16:00", "16:00-17:00", "17:00-18:00", "18:00-19:00", "19:00-20:00", "20:00-21:00", "21:00-22:00",
              "22:00-23:00", "23:00-24:00"]
taxi_dataQ2["Time Category"] = pd.cut(taxi_dataQ2["Pickup Time"], bins, labels=group_names)

# Count the number of trips in each bin
taxi_dataQ2 = taxi_dataQ2.groupby("Time Category").count()
taxi_dataQ2.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a89429db74dd> in <module>
#       6               "15:00-16:00", "16:00-17:00", "17:00-18:00", "18:00-19:00", "19:00-20:00", "20:00-21:00", "21:00-22:00",
#       7               "22:00-23:00", "23:00-24:00"]
# ----> 8 taxi_dataQ2["Time Category"] = pd.cut(taxi_dataQ2["Pickup Time"], bins, labels=group_names)
#       9
#      10 # Count the number of trips in each bin
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     232             bins = np.asarray(bins)
#     233         bins = _convert_bin_to_numeric_type(bins, dtype)
# --> 234         if (np.diff(bins) < 0).any():
#     235             raise ValueError('bins must increase monotonically.')
#     236
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in diff(a, n, axis, prepend, append)
#    1271     op = not_equal if a.dtype == np.bool_ else subtract
#    1272     for _ in range(n):
# -> 1273         a = op(a[slice1], a[slice2])
#    1274
#    1275     return a
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U5') dtype('<U5') dtype('<U5')

# %% [markdown]
# # Collision

# %%
collision= pd.read_csv('clean_collision_final.csv')
collision.head()
# Out:
#    Unnamed: 0  Year            Date_Time Collision Type Descriptor  \
# 0           0  2016  2016-05-15 10:38:00                   HEAD ON
# 1           1  2016  2016-05-20 00:00:00                   Unknown
# 2           2  2016  2016-08-15 19:29:00                     OTHER
# 3           3  2016  2016-03-30 12:55:00                OVERTAKING
# 4           4  2016  2016-07-09 20:10:00                     OTHER
#
#   Road Surface Conditions Weather Conditions  Number of Vehicles Involved
# 0                     Dry             Cloudy                            2
# 1                     Dry              Clear                            2
# 2                     Dry             Cloudy                            1
# 3                     Dry              Clear                            2
# 4                     Wet               Rain                            1

# %%
collision['datetime'] =  pd.to_datetime(collision['Date_Time'], format='%Y-%m-%d %H:%M')
collision['Hour']= collision['datetime'].dt.hour
collision['Year']= collision['datetime'].dt.year
collision['Month']= collision['datetime'].dt.month
collision['Day']=collision['datetime'].dt.day
collision = collision.assign(datetime=collision.datetime.dt.round('H'))
columnshead = ['datetime','Year','Month', 'Day', 'Hour', 'Collision Type Descriptor', 'Road Surface Conditions','Weather Conditions','Number of Vehicles Involved']
collision = collision.reindex(columns= columnshead)
collision.head()
# Out:
#              datetime  Year  Month  Day  Hour Collision Type Descriptor  \
# 0 2016-05-15 11:00:00  2016      5   15    10                   HEAD ON
# 1 2016-05-20 00:00:00  2016      5   20     0                   Unknown
# 2 2016-08-15 19:00:00  2016      8   15    19                     OTHER
# 3 2016-03-30 13:00:00  2016      3   30    12                OVERTAKING
# 4 2016-07-09 20:00:00  2016      7    9    20                     OTHER
#
#   Road Surface Conditions Weather Conditions  Number of Vehicles Involved
# 0                     Dry             Cloudy                            2
# 1                     Dry              Clear                            2
# 2                     Dry             Cloudy                            1
# 3                     Dry              Clear                            2
# 4                     Wet               Rain                            1

# %%
collision_data = pd.merge(collision, weather_data_NY, on=['Year','Month','Day','Hour'], how='left')
collision_data = collision_data.round({'Temp(K)': 0, 'Temp(C)': 0})
collision_data.head()
# Out:
#            datetime_x  Year  Month  Day  Hour Collision Type Descriptor  \
# 0 2016-05-15 11:00:00  2016      5   15    10                   HEAD ON
# 1 2016-05-20 00:00:00  2016      5   20     0                   Unknown
# 2 2016-08-15 19:00:00  2016      8   15    19                     OTHER
# 3 2016-03-30 13:00:00  2016      3   30    12                OVERTAKING
# 4 2016-07-09 20:00:00  2016      7    9    20                     OTHER
#
#   Road Surface Conditions Weather Conditions  Number of Vehicles Involved  \
# 0                     Dry             Cloudy                            2
# 1                     Dry              Clear                            2
# 2                     Dry             Cloudy                            1
# 3                     Dry              Clear                            2
# 4                     Wet               Rain                            1
#
#            datetime_y  Temp(K)  Temp(C)  Humidity(%)  Pressure(Torr)  \
# 0 2016-05-15 10:00:00    282.0      8.0         70.0          1008.0
# 1 2016-05-20 00:00:00    291.0     17.0         55.0          1019.0
# 2 2016-08-15 19:00:00    305.0     32.0         44.0          1020.0
# 3 2016-03-30 12:00:00    275.0      2.0         38.0          1029.0
# 4 2016-07-09 20:00:00    294.0     21.0         83.0          1011.0
#
#             Weather  Wind Speed
# 0      sky is clear         2.0
# 1  scattered clouds         5.0
# 2      sky is clear         1.0
# 3        few clouds         2.0
# 4              mist         3.0
