# %%
import pandas as pd
import numpy as np

# %%
data_motor= pd.read_csv('Motor_Vehicle_Crashes_-_Case_Information__Three_Year_Window.csv')
data_motor
# Out:
#         Year                   Crash Descriptor   Time        Date  \
# 0       2014                    Injury Accident   5:35  06/18/2014
# 1       2014           Property Damage Accident  15:28  11/06/2014
# 2       2014           Property Damage Accident  15:27  03/19/2014
# 3       2014           Property Damage Accident   4:03  06/23/2014
# 4       2014           Property Damage Accident  15:28  09/27/2014
# 5       2014           Property Damage Accident  18:01  02/12/2014
# 6       2014                    Injury Accident  17:15  10/02/2014
# 7       2014                    Injury Accident   8:28  09/22/2014
# 8       2014                    Injury Accident  14:25  06/05/2014
# 9       2014                    Injury Accident  15:15  03/27/2014
# 10      2014           Property Damage Accident  14:30  12/26/2014
# 11      2014           Property Damage Accident  14:10  10/13/2014
# 12      2014                    Injury Accident  15:30  05/19/2014
# ...

# %%
subset = data_motor[['Year','Time', 'Date', 'Collision Type Descriptor', 'Road Surface Conditions', 'Weather Conditions', 'Number of Vehicles Involved']]
subset
# Out:
#         Year   Time        Date Collision Type Descriptor  \
# 0       2014   5:35  06/18/2014                     OTHER
# 1       2014  15:28  11/06/2014               RIGHT ANGLE
# 2       2014  15:27  03/19/2014                OVERTAKING
# 3       2014   4:03  06/23/2014                     OTHER
# 4       2014  15:28  09/27/2014                     OTHER
# 5       2014  18:01  02/12/2014                     OTHER
# 6       2014  17:15  10/02/2014                OVERTAKING
# 7       2014   8:28  09/22/2014                  REAR END
# 8       2014  14:25  06/05/2014                     OTHER
# 9       2014  15:15  03/27/2014                   Unknown
# 10      2014  14:30  12/26/2014                  REAR END
# 11      2014  14:10  10/13/2014                     OTHER
# 12      2014  15:30  05/19/2014                  REAR END
# 13      2014  16:35  02/14/2014               RIGHT ANGLE
# 14      2014  18:23  08/07/2014                   Unknown
# ...

# %%
subset[subset['Year'] >=2016]
# Out:
# Year                                  2014
# Time                                 16:18
# Date                            11/28/2014
# Collision Type Descriptor      RIGHT ANGLE
# Road Surface Conditions                Dry
# Weather Conditions                   Clear
# Number of Vehicles Involved              2
# Name: 2016, dtype: object

# %%
data_year.to_csv("clean_collision.csv", mode="w")
